# %% [markdown]
# <a href="https://colab.research.google.com/github/CJO100293/Project-4/blob/main/ETL/ETL_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing the Needed Dependencies
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import pandas as pd
import numpy as np
pd.set_option('max_colwidth', 400)
import os
import csv
from pprint import pprint
from pathlib import Path
from google.colab import drive

# %%
# Mouting Google Drive Account
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Create reference to CSV file
url = "https://nextcloud.unknowntunnel.com/s/9sPFBptTjtyPDKK/download/credit_data.csv"

# Import the CSV into a pandas DataFrame
credit_data_df = pd.read_csv(url)

# Display dataframe
credit_data_df.head()
# Out:
#                                 Loan ID                           Customer ID  \
# 0  f738779f-c726-40dc-92cf-689d73af533d  ded0b3c3-6bf4-4091-8726-47039f2c1b90
# 1  6dcc0947-164d-476c-a1de-3ae7283dde0a  1630e6e3-34e3-461a-8fda-09297d3140c8
# 2  f7744d01-894b-49c3-8777-fc6431a2cff1  2c60938b-ad2b-4702-804d-eeca43949c52
# 3  83721ffb-b99a-4a0f-aea5-ef472a138b41  12116614-2f3c-4d16-ad34-d92883718806
# 4  08f3789f-5714-4b10-929d-e1527ab5e5a3  39888105-fd5f-4023-860a-30a3e6f5ccb7
#
#    Current Loan Amount        Term  Credit Score  Annual Income  \
# 0               611314  Short Term         747.0      2074116.0
# 1               266662  Short Term         734.0      1919190.0
# 2               153494  Short Term         709.0       871112.0
# 3               176242  Short Term         727.0       780083.0
# 4               321992  Short Term         744.0      1761148.0
#
#   Years in current job Home Ownership             Purpose  Monthly Debt  \
# 0            10+ years  Home Mortgage  Debt Consolidation      42000.83
# 1            10+ years  Home Mortgage  Debt Consolidation      36624.40
# 2              2 years           Rent  Debt Consolidation       8391.73
# 3            10+ years           Rent  Debt Consolidation      16771.87
# 4            10+ years  Home Mortgage  Debt Consolidation      39478.77
#
#    Years of Credit History  Months since last delinquent  \
# 0                     21.8                           NaN
# 1                     19.4                           NaN
# 2                     12.5                          10.0
# 3                     16.5                          27.0
# 4                     26.0                          44.0
#
#    Number of Open Accounts  Number of Credit Problems  Current Credit Balance  \
# 0                        9                          0                  621908
# 1                       11                          0                  679573
# 2                       10                          0                   38532
# 3                       16                          1                  156940
# 4                       14                          0                  359765
#
#    Maximum Open Credit  Bankruptcies  Tax Liens
# 0              1058970           0.0        0.0
# 1               904442           0.0        0.0
# 2               388036           0.0        0.0
# 3               531322           1.0        0.0
# 4               468072           0.0        0.0

# %%
# Dropping unneeded columns
credit_data_df = credit_data_df.drop(['Term', 'Years in current job',
                                      'Loan ID', 'Customer ID',
                                      'Home Ownership', 'Tax Liens'], axis=1)
# Display dataframe
credit_data_df.head()
# Out:
#    Current Loan Amount  Credit Score  Annual Income             Purpose  \
# 0               611314         747.0      2074116.0  Debt Consolidation
# 1               266662         734.0      1919190.0  Debt Consolidation
# 2               153494         709.0       871112.0  Debt Consolidation
# 3               176242         727.0       780083.0  Debt Consolidation
# 4               321992         744.0      1761148.0  Debt Consolidation
#
#    Monthly Debt  Years of Credit History  Months since last delinquent  \
# 0      42000.83                     21.8                           NaN
# 1      36624.40                     19.4                           NaN
# 2       8391.73                     12.5                          10.0
# 3      16771.87                     16.5                          27.0
# 4      39478.77                     26.0                          44.0
#
#    Number of Open Accounts  Number of Credit Problems  Current Credit Balance  \
# 0                        9                          0                  621908
# 1                       11                          0                  679573
# 2                       10                          0                   38532
# 3                       16                          1                  156940
# 4                       14                          0                  359765
#
#    Maximum Open Credit  Bankruptcies
# 0              1058970           0.0
# 1               904442           0.0
# 2               388036           0.0
# 3               531322           1.0
# 4               468072           0.0

# %%
# Adding "Monthly Income" column by taking the "Annual Income" column and dividing it by 12.

# Adding months variable
months = 12

# Adding new "monthly income" column by deviding the "Annual Income" column by 12.
credit_data_df['Monthly Income'] = (credit_data_df['Annual Income'] / months).round(2)

# Display Dataframe
credit_data_df.head()
# Out:
#    Current Loan Amount  Credit Score  Annual Income             Purpose  \
# 0               611314         747.0      2074116.0  Debt Consolidation
# 1               266662         734.0      1919190.0  Debt Consolidation
# 2               153494         709.0       871112.0  Debt Consolidation
# 3               176242         727.0       780083.0  Debt Consolidation
# 4               321992         744.0      1761148.0  Debt Consolidation
#
#    Monthly Debt  Years of Credit History  Months since last delinquent  \
# 0      42000.83                     21.8                           NaN
# 1      36624.40                     19.4                           NaN
# 2       8391.73                     12.5                          10.0
# 3      16771.87                     16.5                          27.0
# 4      39478.77                     26.0                          44.0
#
#    Number of Open Accounts  Number of Credit Problems  Current Credit Balance  \
# 0                        9                          0                  621908
# 1                       11                          0                  679573
# 2                       10                          0                   38532
# 3                       16                          1                  156940
# 4                       14                          0                  359765
#
#    Maximum Open Credit  Bankruptcies  Monthly Income
# 0              1058970           0.0       172843.00
# 1               904442           0.0       159932.50
# 2               388036           0.0        72592.67
# 3               531322           1.0        65006.92
# 4               468072           0.0       146762.33

# %%
# Adding "Debt-Income Ratio" column by taking the "Monthly Debt" column and dividing it by the 'Monthly Income' column.
#credit_data_df['Debt / Income Ratio'] = credit_data_df['Monthly Debt']/credit_data_df['Monthly Income']*100
credit_data_df['Debt / Income Ratio'] = credit_data_df['Monthly Debt']/credit_data_df['Monthly Income']

#Display Dataframe
credit_data_df.head()
# Out:
#    Current Loan Amount  Credit Score  Annual Income             Purpose  \
# 0               611314         747.0      2074116.0  Debt Consolidation
# 1               266662         734.0      1919190.0  Debt Consolidation
# 2               153494         709.0       871112.0  Debt Consolidation
# 3               176242         727.0       780083.0  Debt Consolidation
# 4               321992         744.0      1761148.0  Debt Consolidation
#
#    Monthly Debt  Years of Credit History  Months since last delinquent  \
# 0      42000.83                     21.8                           NaN
# 1      36624.40                     19.4                           NaN
# 2       8391.73                     12.5                          10.0
# 3      16771.87                     16.5                          27.0
# 4      39478.77                     26.0                          44.0
#
#    Number of Open Accounts  Number of Credit Problems  Current Credit Balance  \
# 0                        9                          0                  621908
# 1                       11                          0                  679573
# 2                       10                          0                   38532
# 3                       16                          1                  156940
# 4                       14                          0                  359765
#
#    Maximum Open Credit  Bankruptcies  Monthly Income  Debt / Income Ratio
# 0              1058970           0.0       172843.00             0.243000
# 1               904442           0.0       159932.50             0.228999
# 2               388036           0.0        72592.67             0.115600
# 3               531322           1.0        65006.92             0.258001
# 4               468072           0.0       146762.33             0.268998

# %%
# Adding "Credit Usage Ratio" column by taking the "Current Credit Balance" column and
# dividing it by the 'Maximum Open Credit' column.
credit_data_df['Credit Usage Ratio'] = credit_data_df['Current Credit Balance']/credit_data_df['Maximum Open Credit']

#Display Dataframe
credit_data_df.head()
# Out:
#    Current Loan Amount  Credit Score  Annual Income             Purpose  \
# 0               611314         747.0      2074116.0  Debt Consolidation
# 1               266662         734.0      1919190.0  Debt Consolidation
# 2               153494         709.0       871112.0  Debt Consolidation
# 3               176242         727.0       780083.0  Debt Consolidation
# 4               321992         744.0      1761148.0  Debt Consolidation
#
#    Monthly Debt  Years of Credit History  Months since last delinquent  \
# 0      42000.83                     21.8                           NaN
# 1      36624.40                     19.4                           NaN
# 2       8391.73                     12.5                          10.0
# 3      16771.87                     16.5                          27.0
# 4      39478.77                     26.0                          44.0
#
#    Number of Open Accounts  Number of Credit Problems  Current Credit Balance  \
# 0                        9                          0                  621908
# 1                       11                          0                  679573
# 2                       10                          0                   38532
# 3                       16                          1                  156940
# 4                       14                          0                  359765
#
#    Maximum Open Credit  Bankruptcies  Monthly Income  Debt / Income Ratio  \
# 0              1058970           0.0       172843.00             0.243000
# 1               904442           0.0       159932.50             0.228999
# 2               388036           0.0        72592.67             0.115600
# 3               531322           1.0        65006.92             0.258001
# 4               468072           0.0       146762.33             0.268998
#
#    Credit Usage Ratio
# 0            0.587276
# 1            0.751373
# 2            0.099300
# 3            0.295376
# 4            0.768610

# %%
# Changing all "NaN" values in all columns to "0"
credit_data_df = credit_data_df.fillna(0)
credit_data_df.head()
# Out:
#    Current Loan Amount  Credit Score  Annual Income             Purpose  \
# 0               611314         747.0      2074116.0  Debt Consolidation
# 1               266662         734.0      1919190.0  Debt Consolidation
# 2               153494         709.0       871112.0  Debt Consolidation
# 3               176242         727.0       780083.0  Debt Consolidation
# 4               321992         744.0      1761148.0  Debt Consolidation
#
#    Monthly Debt  Years of Credit History  Months since last delinquent  \
# 0      42000.83                     21.8                           0.0
# 1      36624.40                     19.4                           0.0
# 2       8391.73                     12.5                          10.0
# 3      16771.87                     16.5                          27.0
# 4      39478.77                     26.0                          44.0
#
#    Number of Open Accounts  Number of Credit Problems  Current Credit Balance  \
# 0                        9                          0                  621908
# 1                       11                          0                  679573
# 2                       10                          0                   38532
# 3                       16                          1                  156940
# 4                       14                          0                  359765
#
#    Maximum Open Credit  Bankruptcies  Monthly Income  Debt / Income Ratio  \
# 0              1058970           0.0       172843.00             0.243000
# 1               904442           0.0       159932.50             0.228999
# 2               388036           0.0        72592.67             0.115600
# 3               531322           1.0        65006.92             0.258001
# 4               468072           0.0       146762.33             0.268998
#
#    Credit Usage Ratio
# 0            0.587276
# 1            0.751373
# 2            0.099300
# 3            0.295376
# 4            0.768610

# %%
# Changing order of columns
credit_data_df = credit_data_df.reindex(['Current Loan Amount', 'Credit Score',
                                         'Annual Income', 'Monthly Income',
                                         'Monthly Debt', 'Debt / Income Ratio', 'Years of Credit History',
                                         'Months since last delinquent',
                                         'Number of Open Accounts', 'Number of Credit Problems',
                                         'Current Credit Balance' ,'Maximum Open Credit',
                                         'Credit Usage Ratio', 'Bankruptcies', 'Purpose'], axis=1)
# Display dataframe
credit_data_df.head()
# Out:
#    Current Loan Amount  Credit Score  Annual Income  Monthly Income  \
# 0               611314         747.0      2074116.0       172843.00
# 1               266662         734.0      1919190.0       159932.50
# 2               153494         709.0       871112.0        72592.67
# 3               176242         727.0       780083.0        65006.92
# 4               321992         744.0      1761148.0       146762.33
#
#    Monthly Debt  Debt / Income Ratio  Years of Credit History  \
# 0      42000.83             0.243000                     21.8
# 1      36624.40             0.228999                     19.4
# 2       8391.73             0.115600                     12.5
# 3      16771.87             0.258001                     16.5
# 4      39478.77             0.268998                     26.0
#
#    Months since last delinquent  Number of Open Accounts  \
# 0                           0.0                        9
# 1                           0.0                       11
# 2                          10.0                       10
# 3                          27.0                       16
# 4                          44.0                       14
#
#    Number of Credit Problems  Current Credit Balance  Maximum Open Credit  \
# 0                          0                  621908              1058970
# 1                          0                  679573               904442
# 2                          0                   38532               388036
# 3                          1                  156940               531322
# 4                          0                  359765               468072
#
#    Credit Usage Ratio  Bankruptcies             Purpose
# 0            0.587276           0.0  Debt Consolidation
# 1            0.751373           0.0  Debt Consolidation
# 2            0.099300           0.0  Debt Consolidation
# 3            0.295376           1.0  Debt Consolidation
# 4            0.768610           0.0  Debt Consolidation

# %%
# Renaming the "Years of Credit History", "Months since last delinquent",
# "Number of Open Accounts", "Number of Credit Problems", "Current Credit Balance",
# "Maximum Open Credit" and "Purpose" columns.
credit_data_df = credit_data_df.rename(columns={"Years of Credit History":"Credit History(Years)",
                                                "Months since last delinquent":"Months Delinquent",
                                                "Number of Open Accounts":"Open Accounts",
                                                "Number of Credit Problems":"Credit Problems",
                                                "Current Credit Balance":"Credit Balance",
                                                "Maximum Open Credit":"Total Credit",
                                                "Purpose":"Loan Purpose"})

# Display dataframe
credit_data_df.head()
# Out:
#    Current Loan Amount  Credit Score  Annual Income  Monthly Income  \
# 0               611314         747.0      2074116.0       172843.00
# 1               266662         734.0      1919190.0       159932.50
# 2               153494         709.0       871112.0        72592.67
# 3               176242         727.0       780083.0        65006.92
# 4               321992         744.0      1761148.0       146762.33
#
#    Monthly Debt  Debt / Income Ratio  Credit History(Years)  \
# 0      42000.83             0.243000                   21.8
# 1      36624.40             0.228999                   19.4
# 2       8391.73             0.115600                   12.5
# 3      16771.87             0.258001                   16.5
# 4      39478.77             0.268998                   26.0
#
#    Months Delinquent  Open Accounts  Credit Problems  Credit Balance  \
# 0                0.0              9                0          621908
# 1                0.0             11                0          679573
# 2               10.0             10                0           38532
# 3               27.0             16                1          156940
# 4               44.0             14                0          359765
#
#    Total Credit  Credit Usage Ratio  Bankruptcies        Loan Purpose
# 0       1058970            0.587276           0.0  Debt Consolidation
# 1        904442            0.751373           0.0  Debt Consolidation
# 2        388036            0.099300           0.0  Debt Consolidation
# 3        531322            0.295376           1.0  Debt Consolidation
# 4        468072            0.768610           0.0  Debt Consolidation

# %%
# Export the newly transformed dataframe into a csv
credit_data_df.to_csv("/content/drive/My Drive/Colab-Notebooks/Project-4/output_data/ETL_credit_data.csv", index=False)

# %%
# Un-Mouting Google Drive Account
drive.flush_and_unmount()
